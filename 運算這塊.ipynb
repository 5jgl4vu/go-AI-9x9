# %% [markdown]
# <a href="https://colab.research.google.com/github/5jgl4vu/go-AI-9x9/blob/main/%E9%81%8B%E7%AE%97%E9%80%99%E5%A1%8A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 切換到 Drive 裡的某個工作目錄，確保檔案不會不見
# %cd /content/drive/MyDrive/

# 建立一個專門放專題的資料夾 (如果還沒建過)
# !mkdir -p MyGoProject
# %cd MyGoProject

# 把 GitHub 的東西抓下來 (換成他們自己的網址)
# !git clone https://github.com/5jgl4vu/go-AI-9x9.git
# Out:
# /content/drive/MyDrive
# /content/drive/MyDrive/MyGoProject
# Cloning into 'go-AI-9x9'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %% [markdown]
# print("I am alive. My Go AI starts here.")
